# %%
import potato

# %%
# HTML content for phenotype datatypes tooltips
html_content_phenotype_datatypes = {
    "pheno_morphological.html": """
    <ul>
        <li>Physical traits observed in organisms</li>
        <li>Includes size, shape, color, and structure</li>
        <li>Often used for species identification</li>
    </ul>
    """,
    "pheno_morphometrics.html": """
    <ul>
        <li>Quantitative analysis of form</li>
        <li>Measures size and shape of organisms</li>
        <li>Used in evolutionary and developmental biology</li>
    </ul>
    """,
    "pheno_qualitative.html": """
    <ul>
        <li>Descriptive features not easily quantified</li>
        <li>Includes color, texture, and patterns</li>
        <li>Important for species identification and classification</li>
    </ul>
    """,
    "pheno_color.html": """
    <ul>
        <li>Color patterns and variations in organisms</li>
        <li>Used to identify and classify species</li>
        <li>Can indicate ecological and evolutionary processes</li>
    </ul>
    """,
    "pheno_shape.html": """
    <ul>
        <li>Shape characteristics of organisms</li>
        <li>Includes body forms, appendages, and structures</li>
        <li>Important for functional and evolutionary studies</li>
    </ul>
    """,
    "pheno_texture.html": """
    <ul>
        <li>Surface quality of organisms</li>
        <li>Includes smoothness, roughness, and patterns</li>
        <li>Can affect organism interactions with the environment</li>
    </ul>
    """,
    "pheno_ultrastructural.html": """
    <ul>
        <li>Detailed structures observed under electron microscopy</li>
        <li>Includes cellular and subcellular features</li>
        <li>Used in taxonomy and functional biology</li>
    </ul>
    """,
    "pheno_interbreeding.html": """
    <ul>
        <li>Study of reproductive compatibility</li>
        <li>Includes genital morphology and hybridization</li>
        <li>Important for understanding species boundaries</li>
    </ul>
    """,
    "pheno_biochemical.html": """
    <ul>
        <li>Chemical composition of organisms</li>
        <li>Includes metabolites and pheromones</li>
        <li>Used in chemotaxonomy and ecological studies</li>
    </ul>
    """,
    "pheno_chemotaxonomy.html": """
    <ul>
        <li>Classification based on chemical compounds</li>
        <li>Includes metabolites and secondary compounds</li>
        <li>Important for species identification and relationships</li>
    </ul>
    """,
    "pheno_cytotaxonomy.html": """
    <ul>
        <li>Study of chromosomal features</li>
        <li>Includes karyotypes and chromosome numbers</li>
        <li>Used for species classification and evolution studies</li>
    </ul>
    """,
    "pheno_behavioral.html": """
    <ul>
        <li>Traits related to organism behavior</li>
        <li>Includes mating, feeding, and social behaviors</li>
        <li>Important for ecological and evolutionary studies</li>
    </ul>
    """,
    "pheno_acoustic.html": """
    <ul>
        <li>Sound production and communication in organisms</li>
        <li>Includes mating calls and territorial signals</li>
        <li>Used in behavioral and ecological studies</li>
    </ul>
    """,
    "pheno_mating.html": """
    <ul>
        <li>Behaviors associated with reproduction</li>
        <li>Includes courtship and copulation</li>
        <li>Important for understanding reproductive strategies</li>
    </ul>
    """,
    "pheno_ecological.html": """
    <ul>
        <li>Traits related to organism's habitat and niche</li>
        <li>Includes habitat preferences and resource use</li>
        <li>Used in ecological and environmental studies</li>
    </ul>
    """,
    "pheno_biogeography.html": """
    <ul>
        <li>Geographical distribution of organisms</li>
        <li>Includes patterns of endemism and dispersal</li>
        <li>Important for understanding evolutionary history</li>
    </ul>
    """,
    "pheno_introgression.html": """
    <ul>
        <li>Gene flow between species through hybridization</li>
        <li>Includes study of hybrid zones and genetic exchange</li>
        <li>Important for evolutionary and genetic studies</li>
    </ul>
    """,
    "pheno_genitals.html": """
    <ul>
        <li>Morphology of reproductive organs</li>
        <li>Includes structures like testes, ovaries, and genitalia</li>
        <li>Used in taxonomy and reproductive biology</li>
    </ul>
    """
}




import os

output_dir = r"C:\Users\conix\immigration_framing\tooltips\new_tooltips2/"
os.makedirs(output_dir, exist_ok=True)

# Save each content to a corresponding HTML file (part 2)
for filename, content in html_content_phenotype_datatypes.items():
    with open(os.path.join(output_dir, filename), 'w') as file:
        file.write(content)

# %%
# HTML content for phenotype data processing and phenotype methods tooltips
html_content_phenotype_processing_methods = {
    "pheno_microscopes.html": """
    <ul>
        <li>Instruments for magnifying small objects</li>
        <li>Includes light, electron, and fluorescence microscopes</li>
        <li>Used in detailed morphological studies</li>
    </ul>
    """,
    "pheno_light_microscopy.html": """
    <ul>
        <li>Use of light to view specimens</li>
        <li>Includes bright field, phase contrast, and DIC</li>
        <li>Common in basic biological research</li>
    </ul>
    """,
    "pheno_tem.html": """
    <ul>
        <li>Transmission electron microscopy</li>
        <li>Uses electrons to view thin specimens</li>
        <li>Provides high-resolution internal structure images</li>
    </ul>
    """,
    "pheno_sem.html": """
    <ul>
        <li>Scanning electron microscopy</li>
        <li>Uses electrons to view specimen surfaces</li>
        <li>Provides detailed 3D surface images</li>
    </ul>
    """,
    "pheno_fluorescence.html": """
    <ul>
        <li>Use of fluorescent dyes to view specimens</li>
        <li>Includes confocal and wide-field microscopy</li>
        <li>Common in cellular and molecular biology</li>
    </ul>
    """,
    "pheno_confocal.html": """
    <ul>
        <li>Advanced fluorescence microscopy</li>
        <li>Uses lasers and optical sectioning</li>
        <li>Provides high-resolution 3D images</li>
    </ul>
    """,
    "pheno_sampling.html": """
    <ul>
        <li>Methods for collecting specimens</li>
        <li>Includes traps, nets, and sediment cores</li>
        <li>Important for field studies and surveys</li>
    </ul>
    """,
    "pheno_filter_membranes.html": """
    <ul>
        <li>Use of membranes to filter samples</li>
        <li>Common in water and environmental sampling</li>
        <li>Used to collect microorganisms and particles</li>
    </ul>
    """,
    "pheno_oxygen_depletion.html": """
    <ul>
        <li>Sampling based on oxygen levels</li>
        <li>Includes methods like hypoxia chambers</li>
        <li>Used in ecological and physiological studies</li>
    </ul>
    """,
    "pheno_magnesium_chloride.html": """
    <ul>
        <li>Decantation using magnesium chloride</li>
        <li>Separates organisms from sediment or debris</li>
        <li>Common in soil and aquatic sampling</li>
    </ul>
    """,
    "pheno_baermann.html": """
    <ul>
        <li>Baermann funnel technique</li>
        <li>Separates nematodes from soil samples</li>
        <li>Used in parasitology and soil biology</li>
    </ul>
    """,
    "pheno_trapping.html": """
    <ul>
        <li>Use of traps to collect specimens</li>
        <li>Includes pitfall, light, and sticky traps</li>
        <li>Common in entomology and wildlife studies</li>
    </ul>
    """,
    "pheno_sediment_cores.html": """
    <ul>
        <li>Sampling sediment layers</li>
        <li>Uses cores or Niskin bottles</li>
        <li>Used in geological and environmental studies</li>
    </ul>
    """,
    "pheno_netting.html": """
    <ul>
        <li>Use of nets for sample collection</li>
        <li>Includes plankton and sweep nets</li>
        <li>Common in aquatic and terrestrial studies</li>
    </ul>
    """,
    "pheno_storage.html": """
    <ul>
        <li>Methods for preserving samples</li>
        <li>Includes freezing, alcohols, and RNAlater</li>
        <li>Ensures sample integrity for analysis</li>
    </ul>
    """,
    "pheno_flash_freezing.html": """
    <ul>
        <li>Rapid freezing of samples</li>
        <li>Preserves cellular structures and molecules</li>
        <li>Common in molecular biology and biochemistry</li>
    </ul>
    """,
    "pheno_multivariate_regression.html": """
    <ul>
        <li>Statistical analysis method</li>
        <li>Uses multiple variables to predict outcomes</li>
        <li>Common in morphological data analysis</li>
    </ul>
    """,
    "pheno_phylogenetic_methods.html": """
    <ul>
        <li>Methods to infer evolutionary relationships</li>
        <li>Uses morphological and genetic data</li>
        <li>Important for understanding species evolution</li>
    </ul>
    """,
    "pheno_species_delimitation.html": """
    <ul>
        <li>Identifying species boundaries</li>
        <li>Uses qualitative data</li>
        <li>'this group is clearly different because of features X, Y and Z'</li>
    </ul>
    """
}



output_dir = r"C:\Users\conix\immigration_framing\tooltips\new_tooltips2/"
os.makedirs(output_dir, exist_ok=True)

for filename, content in html_content_phenotype_processing_methods.items():
    with open(os.path.join(output_dir, filename), 'w') as file:
        file.write(content)

# %%
# HTML content for genotype datatypes tooltips
html_content_genotype_datatypes = {
    "genotype_nuclear_dna.html": """
    <ul>
        <li>DNA found in the cell nucleus</li>
        <li>Includes most genetic material in eukaryotes</li>
        <li>Used in genetic and evolutionary studies</li>
    </ul>
    """,
    "genotype_organellar_dna.html": """
    <ul>
        <li>DNA found in organelles like mitochondria and chloroplasts</li>
        <li>Important for studies on maternal inheritance</li>
        <li>Used in phylogenetic and evolutionary research</li>
    </ul>
    """,
    "genotype_transcriptomic.html": """
    <ul>
        <li>Study of RNA transcripts produced by the genome</li>
        <li>Includes mRNA, rRNA, tRNA, and other non-coding RNAs</li>
        <li>Important for gene expression and functional genomics</li>
    </ul>
    """,
    "genotype_proteomic.html": """
    <ul>
        <li>Study of the entire set of proteins expressed by a genome</li>
        <li>Includes protein structure and function</li>
        <li>Important for understanding cellular processes</li>
    </ul>
    """,
    "genotype_microsatellites.html": """
    <ul>
        <li>Short, repeating sequences of DNA</li>
        <li>Also known as short tandem repeats (STRs)</li>
        <li>Used in genetic mapping and population studies</li>
    </ul>
    """,
    "genotype_whole_genomes.html": """
    <ul>
        <li>Complete DNA sequence of an organism's genome</li>
        <li>Includes all genes and non-coding regions</li>
        <li>Used in comprehensive genetic analysis</li>
    </ul>
    """,
    "genotype_exomes.html": """
    <ul>
        <li>All the coding regions of the genome</li>
        <li>Includes exons that are transcribed into mRNA</li>
        <li>Important for identifying gene variants and mutations</li>
    </ul>
    """,
    "genotype_genome_wide.html": """
    <ul>
        <li>Study of genetic variations across the entire genome</li>
        <li>Includes single nucleotide polymorphisms (SNPs)</li>
        <li>Used in association studies and genetic mapping</li>
    </ul>
    """,
    "genotype_epigenetic.html": """
    <ul>
        <li>Study of heritable changes in gene function</li>
        <li>Includes DNA methylation and histone modification</li>
        <li>Important for understanding gene regulation</li>
    </ul>
    """,
    "genotype_edna.html": """
    <ul>
        <li>Environmental DNA collected from soil, water, or air</li>
        <li>Used to detect and monitor organisms in an environment</li>
        <li>Important for biodiversity and conservation studies</li>
    </ul>
    """
}

output_dir = r"C:\Users\conix\immigration_framing\tooltips\new_tooltips2/"
os.makedirs(output_dir, exist_ok=True)

for filename, content in html_content_phenotype_datatypes.items():
    with open(os.path.join(output_dir, filename), 'w') as file:
        file.write(content)

output_dir
# Out:
# 'C:\\Users\\conix\\immigration_framing\\tooltips\\new_tooltips2/'

# %%
# HTML content for genotype data processing tooltips
html_content_genotype_data_processing = {
    "genotype_nucleotide_sequencing.html": """
    <ul>
        <li>Determining the sequence of nucleotides in DNA</li>
        <li>Includes various sequencing technologies</li>
        <li>Important for genetic and genomic studies</li>
    </ul>
    """,
    "genotype_library_preparation.html": """
    <ul>
        <li>Preparing DNA or RNA samples for sequencing</li>
        <li>Includes fragmentation, adapter ligation, and amplification</li>
        <li>Essential for high-throughput sequencing</li>
    </ul>
    """,
    "genotype_first_generation.html": """
    <ul>
        <li>Also known as Sanger sequencing</li>
        <li>Uses chain-termination method to sequence DNA</li>
        <li>Widely used for smaller-scale sequencing projects</li>
    </ul>
    """,
    "genotype_second_generation.html": """
    <ul>
        <li>Next-generation sequencing (NGS) technologies</li>
        <li>Includes Illumina, Ion Torrent, and 454 pyrosequencing</li>
        <li>Enables high-throughput and large-scale sequencing</li>
    </ul>
    """,
    "genotype_third_generation.html": """
    <ul>
        <li>Single-molecule sequencing technologies</li>
        <li>Includes PacBio and Oxford Nanopore</li>
        <li>Allows for long-read sequencing without PCR amplification</li>
    </ul>
    """
}




output_dir = r"C:\Users\conix\immigration_framing\tooltips\new_tooltips2/"
os.makedirs(output_dir, exist_ok=True)

for filename, content in html_content_genotype_data_processing.items():
    with open(os.path.join(output_dir, filename), 'w') as file:
        file.write(content)

output_dir
# Out:
# 'C:\\Users\\conix\\immigration_framing\\tooltips\\new_tooltips2/'

# %%
html_content_genotype_methods = {
    "genotype_distance.html": """
    <ul>
        <li>Non phylogenetic molecular method</li>
        <li>Methods for measuring genetic distances</li>
        <li>Includes pairwise comparisons and distance matrices</li>
        <li>Used for constructing phylogenetic trees and clustering</li>
    </ul>
    """,
    "genotype_haplowebs.html": """
    <ul>
        <li>Non phylogenetic molecular method</li>
        <li>Approaches based on allele sharing</li>
        <li>Uses haplotype networks to infer relationships</li>
        <li>Important for population genetics and phylogeography</li>
    </ul>
    """,
    "genotype_fixed_alternative.html": """
    <ul>
        <li>Non phylogenetic molecular method</li>
        <li>Methods using fixed alternative character states</li>
        <li>Identifies unique genetic markers for species</li>
        <li>Used in species delimitation and identification</li>
    </ul>
    """,
    "genotype_clustering.html": """
    <ul>
        <li>Non phylogenetic molecular method</li>
        <li>Clustering methods for genetic data</li>
        <li>Includes STRUCTURE, STRUCTURAMA, BAPS, and DAPC</li>
        <li>Used to infer population structure and assignment</li>
    </ul>
    """,
    "genotype_interbreeding.html": """
    <ul>
        <li>Non phylogenetic molecular method</li>
        <li>Study of interbreeding between species</li>
        <li>Includes hybrid zones and gene flow analysis</li>
        <li>Important for understanding species boundaries</li>
    </ul>
    """,
    "genotype_gmyc.html": """
    <ul>
        <li>phylogenetic species delimitation</li>
        <li>single locus methoc</li>
        <li>General Mixed Yule Coalescent method</li>
        <li>Used to delimit species based on branching patterns</li>
        <li>Applies coalescent theory to phylogenetic trees</li>
    </ul>
    """,
    "genotype_ptp.html": """
    <ul>
        <li>phylogenetic species delimitation</li>
        <li>single locus methoc</li>
        <li>Poisson Tree Process method</li>
        <li>Species delimitation based on branching rates</li>
        <li>Used for identifying species boundaries in phylogenies</li>
    </ul>
    """,
    "genotype_multi_species_coalescent.html": """
    <ul>
        <li>phylogenetic species delimitation</li>
        <li>multi locus method and genome wide</li>
        <li>Methods using multi-species coalescent models</li>
        <li>Includes SpeDeSTEM, BP&P, Brownie, SNAPP, mPTP, and *BEAST</li>
        <li>Used to infer species relationships and divergence</li>
    </ul>
    """,
    "genotype_posterior_probabilities.html": """
    <ul>
        <li>phylogenetic species delimitation</li>
        <li>multi locus method and genome wide</li>
        <li>Posterior probabilities for species delimitation models</li>
        <li>Used in Bayesian model selection</li>
        <li>Helps determine the best fit model for species boundaries</li>
    </ul>
    """,
    "genotype_bayes_factor.html": """
    <ul>
        <li>phylogenetic species delimitation</li>
        <li>multi locus method and genome wide</li>
        <li>Bayes factor delimitation methods</li>
        <li>Uses Bayes factors for model comparison</li>
        <li>Important for selecting among species delimitation models</li>
    </ul>
    """,
    "genotype_genealogical_divergence.html": """
    <ul>
        <li>phylogenetic species delimitation</li>
        <li>multi locus method and genome wide</li>
        <li>Genealogical Divergence Index (GDI)</li>
        <li>Measures divergence between species</li>
        <li>Used to infer species boundaries and evolutionary history</li>
    </ul>
    """,
    "genotype_distance_based.html": """
    <ul>
        <li>tree reconstruction method</li>
        <li>Distance-based methods for phylogenetic tree construction</li>
        <li>Includes Neighbor Joining and UPGMA</li>
        <li>Used to infer evolutionary relationships</li>
    </ul>
    """,
    "genotype_max_parsimony.html": """
    <ul>
        <li>tree reconstruction method</li>
        <li>character based tree reconstruction</li>
        <li>Maximum Parsimony method for phylogenetic analysis</li>
        <li>Identifies the tree with the least evolutionary changes</li>
        <li>Used in evolutionary biology and systematics</li>
    </ul>
    """,
    "genotype_max_likelihood.html": """
    <ul>
        <li>tree reconstruction method</li>
        <li>character based tree reconstruction</li>
        <li>Maximum Likelihood method for phylogenetic analysis</li>
        <li>Estimates tree likelihood based on genetic data</li>
        <li>Provides a statistical framework for tree inference</li>
    </ul>
    """,
    "genotype_bayesian_methods.html": """
    <ul>
        <li>tree reconstruction method</li>
        <li>character based tree reconstruction</li>
        <li>Bayesian methods for phylogenetic analysis</li>
        <li>Includes BEAST and MrBayes</li>
        <li>Uses probability models to infer evolutionary relationships</li>
    </ul>
    """,
    "genotype_consensus_supertree.html": """
    <ul>
        <li>tree reconstruction method</li>
        <li>Consensus and supertree methods</li>
        <li>Combines multiple phylogenetic trees into a single consensus</li>
        <li>Used to summarize and compare different tree hypotheses</li>
    </ul>
    """,
    "genotype_other.html": """
    <ul>
        <li>tree reconstruction method</li>
        <li>Other methods for genetic analysis</li>
        <li>Includes various specialized techniques</li>
        <li>Used for diverse genetic and evolutionary studies</li>
    </ul>
    """,
    "genotype_machine_learning.html": """
    <ul>
        <li>Machine learning methods for genetic data analysis</li>
        <li>Includes supervised, unsupervised, and neural network approaches</li>
        <li>Used for pattern recognition and predictive modeling</li>
    </ul>
    """
}

output_dir = r"C:\Users\conix\immigration_framing\tooltips\new_tooltips2/"
os.makedirs(output_dir, exist_ok=True)

for filename, content in html_content_genotype_methods.items():
    with open(os.path.join(output_dir, filename), 'w') as file:
        file.write(content)

output_dir
# Out:
# 'C:\\Users\\conix\\immigration_framing\\tooltips\\new_tooltips2/'

# %%
# Reimporting os module and setting the output directory again

import os

output_dir = r"C:\Users\conix\immigration_framing\tooltips\new_tooltips2/"
os.makedirs(output_dir, exist_ok=True)

# Save each content to a corresponding HTML file (part 2)
for filename, content in html_content.items():
    with open(os.path.join(output_dir, filename), 'w') as file:
        file.write(content)

output_dir
# Out:
# 'C:\\Users\\conix\\immigration_framing\\tooltips\\new_tooltips2/'
